# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel(r'E:\AI Projects\ML Course\ReinforcementLearning\Ads.xlsx')

# %%
final_list = [0] * 10
Number_of_Rows = 60

for r in range(0, Number_of_Rows):
    for c in range(0,10):
        pointer = dataset.iloc[r,c]
        if(pointer > 0):
            final_list[c] = final_list[c] + 1

print(final_list)
# Out:
# [10, 12, 6, 16, 8, 4, 6, 6, 8, 11]

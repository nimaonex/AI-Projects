# %% [markdown]
# for complex situations, where we can't classify the dataset by a linear line, to separate non-linear dataset
# one way is to mapping dataset to a higher dimension, for example, make (x-5) to (x-5)^2 for separation
# or by mapping 2D space into 3D space
#
# Gaussian RBF Kernel(a radial basis function): set landmarks(usually in the middle) and measure the distances by the formula
# sigma in this method used for clarfy the boundry for classification
#
# for more complex datasets we can use more kernel functions and adding them to each other
#
# Other functions:
# Sigmoid Kernel
# Polynomial Kernel
#
# hyperplane: when we map dataset from 2d to 3d, we need a 3d linear plate to separate the space
# then add two new plates for up and down support

# %%
from sklearn.svm import SVC 
classifier = SVC(kernel= 'rbf', random_state= 0)
classifier.fit(x_train, y_train)
